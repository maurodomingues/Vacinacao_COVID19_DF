# %% [markdown]
# ##### Bibliotecas

# %%
import os
import numpy as np
import pandas as pd
import openpyxl
#import plotly.io as pio

# %% [markdown]
# ##### Globais

# %%
diretorio  = 'Dataset'

# %%
#pio.renderers.default = 'notebook'  # Configura o renderizador para notebook

# %% [markdown]
# ___
# ##### Conjunto de Dados - openDataSus
#
# *Registros de Vacinação COVID19 no Distrito Federal:*
# https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/5093679f-12c3-4d6b-b7bd-07694de54173
#
# A análise será realizada no **Conjunto de Dados de Vacinação COVID19 (Primeira dose a 30/09/2023)**, considerando somente os **Dados do DF**, totalizando 5 arquivos *csv*.
# <br><br>
# ___

# %% [markdown]
# ##### Análise da Estrutura dos Dados (antes da limpeza)

# %%
df_dados          = pd.DataFrame()    
df_estrutra_dados = pd.DataFrame()
lista_arquivos    = []

# Lista os arquivos do diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
       lista_arquivos.append(arquivo) 
       
# Carrega o DataFrame 
for dataset in lista_arquivos:
    caminho_arquivo   = os.path.join(diretorio, dataset)
    df_dados          = pd.read_csv(caminho_arquivo, sep=';', low_memory=False)
    df_estrutra_dados = pd.concat([df_estrutra_dados, df_dados], ignore_index=True)

# %% [markdown]
# ##### Estrutura da Base de Dados

# %%
df_estrutra_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7903355 entries, 0 to 7903354
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                object
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         float64
#  8   paciente_endereco_coPais                  float64
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     float64
#  13  paciente_nacionalidade_enumNacionalidade  object
#  14  estabelecimento_valor                     int64
#  15  estabelecimento_razaoSocial               object
#  16  estalecimento_noFantasia                  object
#  17  estabelecimento_municipio_codigo          int64
#  18  estabelecimento_municipio_nome            object
#  19  estabelecimento_uf                        object
#  20  vacina_grupoAtendimento_codigo            float64
#  21  vacina_grupoAtendimento_nome              object
#  22  vacina_categoria_codigo                   float64
#  23  vacina_categoria_nome                     object
#  24  vacina_lote                               object
#  25  vacina_fabricante_nome                    object
#  26  vacina_fabricante_referencia              object
#  27  vacina_dataAplicacao                      object
#  28  vacina_descricao_dose                     object
#  29  vacina_codigo                             int64
#  30  vacina_nome                               object
#  31  sistema_origem                            object
# dtypes: float64(7), int64(3), object(22)
# memory usage: 1.9+ GB

# %% [markdown]
# ##### Campos nulos

# %%
df_estrutra_dados.isnull().sum()
# Out:
# document_id                                       0
# paciente_id                                      34
# paciente_idade                                   34
# paciente_dataNascimento                          34
# paciente_enumSexoBiologico                       34
# paciente_racaCor_codigo                          38
# paciente_racaCor_valor                           38
# paciente_endereco_coIbgeMunicipio             65517
# paciente_endereco_coPais                      65302
# paciente_endereco_nmMunicipio                 65437
# paciente_endereco_nmPais                      65302
# paciente_endereco_uf                          65517
# paciente_endereco_cep                       1217387
# paciente_nacionalidade_enumNacionalidade       3744
# estabelecimento_valor                             0
# estabelecimento_razaoSocial                       0
# estalecimento_noFantasia                          0
# estabelecimento_municipio_codigo                  0
# estabelecimento_municipio_nome                    0
# estabelecimento_uf                                0
# vacina_grupoAtendimento_codigo                 2402
# vacina_grupoAtendimento_nome                  47520
# vacina_categoria_codigo                      368005
# vacina_categoria_nome                        368005
# vacina_lote                                       0
# vacina_fabricante_nome                            0
# vacina_fabricante_referencia                  12794
# vacina_dataAplicacao                              0
# vacina_descricao_dose                            11
# vacina_codigo                                     0
# vacina_nome                                     137
# sistema_origem                                 1301
# dtype: int64

# %% [markdown]
# ##### Verificação da UF do vacinado

# %%
df_estrutra_dados['paciente_endereco_uf'].unique()
# Out:
# array(['DF', 'GO', 'PA', 'SP', 'MA', 'MG', 'RJ', 'BA', 'PR', 'PI', 'PE',
#        'CE', 'AL', 'TO', 'RS', nan, 'RN', 'AM', 'PB', 'MS', 'AP', 'MT',
#        'SC', 'XX', 'ES', 'RO', 'SE', 'AC', 'RR'], dtype=object)

# %% [markdown]
# ##### Visualização do DataFrame (Head e Tail)

# %%
print(display(df_estrutra_dados))
# Out:
#                                        document_id  \
# 0        56bcfea3-9436-4678-9a41-596c91357b61-i0b0
# 1        408a40d6-d82a-4649-92d1-9efc80558bb4-i0b0
# 2        56c01666-2538-401c-9471-55ab37268a07-i0b0
# 3        409285c9-118f-442f-9ce5-71f8c051d137-i0b0
# 4        56cc156b-6554-4c0e-9448-636869ff33ac-i0b0
# ...                                            ...
# 7903350  850ec6df-70be-4177-8170-214b92471b7c-i0b0
# 7903351  850f8b13-1ac1-4ca8-8557-b93cb961f488-i0b0
# 7903352  85139415-e12e-4fa2-818d-6c8c1ff2e788-i0b0
# 7903353  8516b6f9-77f8-41fe-9ba2-f508b6cb3611-i0b0
# 7903354  8518eefa-91d5-4702-a514-ffebc649fa1c-i0b0
#
#                                                paciente_id  paciente_idade  \
# 0        5b62f49735c2d6379c99a78d3e84e7dfddad41c5bf4a50...             5.0
# 1        930ed98a1c35319474dcd0c81a0624068dd5571242b940...            49.0
# 2        015eef18137eb5a9833ff47e14c66e731478c70e974ddd...            16.0
# 3        a8e9d6a5d1813394c5e446588a222d7df2625ca058c142...            69.0
# 4        a2857c4631631b5000b41d574ff8d3daa30a2e2386a5f2...            49.0
# ...                                                    ...             ...
# 7903350  5125de1087b3e1ae176928530db97b21cc2cacf68d8e10...            28.0
# 7903351  78efe1bbfca7f7abc28356961b60638bf465d0f85a562a...            47.0
# 7903352  eb55d047d43fc31ef2551c8cf1f1f483195630711db4b7...            54.0
# 7903353  3248bc382b05f9904fcc359cc2c6f790d0803cb352b505...            35.0
# 7903354  32fba164f10e41a7921de54926d5a3f68454f8ba5dd21d...            43.0
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                    2017-01-07                          F
# 1                    1971-07-22                          F
# 2                    2005-10-14                          F
# 3                    1952-07-23                          M
# 4                    1972-08-06                          M
# ...                         ...                        ...
# 7903350              1995-06-14                          F
# 7903351              1973-12-09                          M
# 7903352              1968-05-13                          M
# 7903353              1987-01-20                          F
# 7903354              1978-10-16                          F
#
#          paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            3.0                  PARDA
# 1                           99.0         SEM INFORMACAO
# 2                            1.0                 BRANCA
# 3                            3.0                  PARDA
# 4                           99.0         SEM INFORMACAO
# ...                          ...                    ...
# 7903350                      1.0                 BRANCA
# 7903351                      3.0                  PARDA
# 7903352                      4.0                AMARELA
# 7903353                     99.0         SEM INFORMACAO
# 7903354                      3.0                  PARDA
#
#          paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                 530010.0                      10.0
# 1                                 530010.0                      10.0
# 2                                 530010.0                      10.0
# 3                                 530010.0                      10.0
# 4                                 521308.0                      10.0
# ...                                    ...                       ...
# 7903350                           530010.0                      10.0
# 7903351                           520180.0                      10.0
# 7903352                           530010.0                      10.0
# 7903353                                NaN                       NaN
# 7903354                           530010.0                      10.0
#
#         paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                            BRASILIA  ...                     NaN
# 1                            BRASILIA  ...                     9.0
# 2                            BRASILIA  ...                   114.0
# 3                            BRASILIA  ...                     2.0
# 4                              MINACU  ...                     2.0
# ...                               ...  ...                     ...
# 7903350                      BRASILIA  ...                     2.0
# 7903351                    ARAGOIANIA  ...                     2.0
# 7903352                      BRASILIA  ...                     2.0
# 7903353                           NaN  ...                     2.0
# 7903354                      BRASILIA  ...                     2.0
#
#           vacina_categoria_nome  vacina_lote  vacina_fabricante_nome  \
# 0                           NaN       FP8290  Pendente Identificação
# 1        Trabalhadores de Saúde    202010021        SINOVAC/BUTANTAN
# 2                        Outros       FH8025                  PFIZER
# 3                  Faixa Etária       FL1940                  PFIZER
# 4                  Faixa Etária   217VCD236W     ASTRAZENECA/FIOCRUZ
# ...                         ...          ...                     ...
# 7903350            Faixa Etária       GJ9239                  PFIZER
# 7903351            Faixa Etária       FJ2594                  PFIZER
# 7903352            Faixa Etária      213J21A                 JANSSEN
# 7903353            Faixa Etária   B202106076        SINOVAC/BUTANTAN
# 7903354            Faixa Etária       FN9509                  PFIZER
#
#          vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                  Organization/28290           2022-03-25
# 1         Organization/61189445000156           2021-01-27
# 2         Organization/00394544000851           2021-10-27
# 3         Organization/00394544000851           2021-11-26
# 4         Organization/33781055000135           2021-08-24
# ...                               ...                  ...
# 7903350                         28290           2023-06-27
# 7903351   Organization/00394544000851           2021-11-18
# 7903352                         30587           2022-06-25
# 7903353              Organization/152           2022-02-22
# 7903354                         28290           2022-06-21
#
#         vacina_descricao_dose  vacina_codigo  \
# 0                     2ª Dose             99
# 1                     1ª Dose             86
# 2                     2ª Dose             87
# 3                     Reforço             87
# 4                     2ª Dose             85
# ...                       ...            ...
# 7903350               Reforço            103
# 7903351               2ª Dose             87
# 7903352            2º Reforço             88
# 7903353               Reforço             86
# 7903354            2º Reforço             87
#
#                                        vacina_nome sistema_origem
# 0           COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1            COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 2                      COVID-19 PFIZER - COMIRNATY       Novo PNI
# 3                      COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4        COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# ...                                            ...            ...
# 7903350      COVID-19 PFIZER - COMIRNATY BIVALENTE       Novo PNI
# 7903351                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 7903352             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
# 7903353      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 7903354                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [7903355 rows x 32 columns]
# None

# %% [markdown]
# ___
# ##### Análise da Estrutura dos Dados (processo de limpeza)

# %% [markdown]
# ##### Alteração de tipos

# %%
df_estrutra_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7903355 entries, 0 to 7903354
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                object
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         float64
#  8   paciente_endereco_coPais                  float64
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     float64
#  13  paciente_nacionalidade_enumNacionalidade  object
#  14  estabelecimento_valor                     int64
#  15  estabelecimento_razaoSocial               object
#  16  estalecimento_noFantasia                  object
#  17  estabelecimento_municipio_codigo          int64
#  18  estabelecimento_municipio_nome            object
#  19  estabelecimento_uf                        object
#  20  vacina_grupoAtendimento_codigo            float64
#  21  vacina_grupoAtendimento_nome              object
#  22  vacina_categoria_codigo                   float64
#  23  vacina_categoria_nome                     object
#  24  vacina_lote                               object
#  25  vacina_fabricante_nome                    object
#  26  vacina_fabricante_referencia              object
#  27  vacina_dataAplicacao                      object
#  28  vacina_descricao_dose                     object
#  29  vacina_codigo                             int64
#  30  vacina_nome                               object
#  31  sistema_origem                            object
# dtypes: float64(7), int64(3), object(22)
# memory usage: 1.9+ GB

# %%
df_dados          = pd.DataFrame()
df_estrutra_dados = pd.DataFrame()
lista_arquivos    = []

# Lista os arquivos do diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.csv'):
       lista_arquivos.append(arquivo) 

# Carrega o DataFrame 
for dataset in lista_arquivos:
    caminho_arquivo = os.path.join(diretorio, dataset)
    df_dados        = pd.read_csv(caminho_arquivo,
                                  sep=';', thousands = '.', decimal = ',',
                                  dtype = {'paciente_enumSexoBiologico': 'category',
                                           'estabelecimento_uf': 'category'})
    df_estrutra_dados = pd.concat([df_estrutra_dados, df_dados], ignore_index=True)

df_estrutra_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7903355 entries, 0 to 7903354
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                category
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         float64
#  8   paciente_endereco_coPais                  float64
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     float64
#  13  paciente_nacionalidade_enumNacionalidade  object
#  14  estabelecimento_valor                     int64
#  15  estabelecimento_razaoSocial               object
#  16  estalecimento_noFantasia                  object
#  17  estabelecimento_municipio_codigo          int64
#  18  estabelecimento_municipio_nome            object
#  19  estabelecimento_uf                        category
#  20  vacina_grupoAtendimento_codigo            float64
#  21  vacina_grupoAtendimento_nome              object
#  22  vacina_categoria_codigo                   float64
#  23  vacina_categoria_nome                     object
#  24  vacina_lote                               object
#  25  vacina_fabricante_nome                    object
#  26  vacina_fabricante_referencia              object
#  27  vacina_dataAplicacao                      object
#  28  vacina_descricao_dose                     object
#  29  vacina_codigo                             int64
#  30  vacina_nome                               object
#  31  sistema_origem                            object
# dtypes: category(2), float64(7), int64(3), object(20)
# memory usage: 1.8+ GB

# %% [markdown]
# ##### Exclusão de registros

# %% [markdown]
# Registros sem identificação do vacinado

# %%
df_estrutra_dados.dropna(subset=['paciente_id'], inplace = True)

df_estrutra_dados.isnull().sum()
# Out:
# document_id                                       0
# paciente_id                                       0
# paciente_idade                                    0
# paciente_dataNascimento                           0
# paciente_enumSexoBiologico                        0
# paciente_racaCor_codigo                           4
# paciente_racaCor_valor                            4
# paciente_endereco_coIbgeMunicipio             65483
# paciente_endereco_coPais                      65268
# paciente_endereco_nmMunicipio                 65403
# paciente_endereco_nmPais                      65268
# paciente_endereco_uf                          65483
# paciente_endereco_cep                       1217353
# paciente_nacionalidade_enumNacionalidade       3710
# estabelecimento_valor                             0
# estabelecimento_razaoSocial                       0
# estalecimento_noFantasia                          0
# estabelecimento_municipio_codigo                  0
# estabelecimento_municipio_nome                    0
# estabelecimento_uf                                0
# vacina_grupoAtendimento_codigo                 2402
# vacina_grupoAtendimento_nome                  47520
# vacina_categoria_codigo                      367997
# vacina_categoria_nome                        367997
# vacina_lote                                       0
# vacina_fabricante_nome                            0
# vacina_fabricante_referencia                  12794
# vacina_dataAplicacao                              0
# vacina_descricao_dose                            11
# vacina_codigo                                     0
# vacina_nome                                     137
# sistema_origem                                 1301
# dtype: int64

# %% [markdown]
# Exclusão dos registros de vacinados de fora do Distrito Federal

# %%
df_pacientes_fora_do_DF = df_estrutra_dados[df_estrutra_dados['paciente_endereco_uf'] != 'DF'].index
df_estrutra_dados       = df_estrutra_dados.drop(df_pacientes_fora_do_DF)

df_estrutra_dados['paciente_endereco_uf'].unique()
# Out:
# array(['DF'], dtype=object)

# %% [markdown]
# Exclusão de colunas não relevantes para a análise

# %%
df_estrutra_dados.drop(columns=['paciente_racaCor_codigo',
                                'paciente_endereco_coIbgeMunicipio',
                                'paciente_endereco_coPais',
                                'paciente_endereco_nmMunicipio',
                                'paciente_endereco_nmPais',
                                'paciente_endereco_cep',
                                'paciente_nacionalidade_enumNacionalidade',
                                'vacina_grupoAtendimento_codigo',
                                'vacina_categoria_codigo',
                                'vacina_fabricante_referencia',
                                'sistema_origem'], inplace=True)

df_estrutra_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6729203 entries, 0 to 7903354
# Data columns (total 21 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   document_id                       object
#  1   paciente_id                       object
#  2   paciente_idade                    float64
#  3   paciente_dataNascimento           object
#  4   paciente_enumSexoBiologico        category
#  5   paciente_racaCor_valor            object
#  6   paciente_endereco_uf              object
#  7   estabelecimento_valor             int64
#  8   estabelecimento_razaoSocial       object
#  9   estalecimento_noFantasia          object
#  10  estabelecimento_municipio_codigo  int64
#  11  estabelecimento_municipio_nome    object
#  12  estabelecimento_uf                category
#  13  vacina_grupoAtendimento_nome      object
#  14  vacina_categoria_nome             object
#  15  vacina_lote                       object
#  16  vacina_fabricante_nome            object
#  17  vacina_dataAplicacao              object
#  18  vacina_descricao_dose             object
#  19  vacina_codigo                     int64
#  20  vacina_nome                       object
# dtypes: category(2), float64(1), int64(3), object(15)
# memory usage: 1.0+ GB

# %% [markdown]
# ##### Atualização de Vacinas sem nome

# %% [markdown]
# Busca

# %%
df_vacina_sem_nome = df_estrutra_dados[df_estrutra_dados['vacina_nome'].isnull()]
df_vacina_sem_nome
# Out:
#                                        document_id  \
# 40203    967a03db-ed90-4099-bb49-5408d067fc87-i0b0
# 193899   af737bd4-9d72-4c3e-b480-589cd5528d6e-i0b0
# 324434   9f97304e-bab3-4293-adce-f5592d791a96-i0b0
# 420539   956a589c-a77f-4064-9fe6-24fdcabe8c92-i0b0
# 423941   6598a083-8cbb-406d-a953-8928a074d3bb-i0b0
# ...                                            ...
# 7466612  1c0abd7f-6490-4dd1-9b87-539b7edb83b2-i0b0
# 7506798  577fc4b3-093d-46c5-a23e-3f9a2ea3db48-i0b0
# 7610908  e69153b4-ac96-46e7-b065-cbf2927ee56b-i0b0
# 7710629  5a52b529-d9b9-450b-a59b-ea1aa4e9d054-i0b0
# 7790710  137c443b-1908-41e6-8437-fd5a563526f1-i0b0
#
#                                                paciente_id  paciente_idade  \
# 40203    9d9f4941f7941bce58d58a84444e4a72a53cc4c4225e48...             0.0
# 193899   9d5e556651121592b84d5a14cbfae36beb178df7eafd53...             1.0
# 324434   18174ff1e8457eec34be1c7769f87e7e43c39dc0389ade...             0.0
# 420539   26cc1d08bb48327fa36e22e159517c80f61f0dc647e872...             0.0
# 423941   2c541b7dbecf4385ce1e575ac5d40d90b8bca46271c31b...             1.0
# ...                                                    ...             ...
# 7466612  19d41c7b29b2d8de2902f865e057c629006e7d6a358890...             2.0
# 7506798  0a4b2335f9dfdaa91288221f12fb64b42b97201ad11fe6...             2.0
# 7610908  d79b369b80cae9fcb78f2ba059a98ee157a78946a87fe5...             2.0
# 7710629  a9ecfb6c5499b45735db20ad2f3d2161abb423d10a76e0...             2.0
# 7790710  fb17ef6bda5e814d91e3f38c37e9f46da9630e5a2dd47d...             2.0
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# 40203                2021-12-09                          F
# 193899               2021-03-13                          M
# 324434               2022-04-30                          M
# 420539               2022-01-18                          M
# 423941               2021-03-07                          M
# ...                         ...                        ...
# 7466612              2020-09-01                          M
# 7506798              2020-08-20                          F
# 7610908              2020-06-30                          M
# 7710629              2020-10-10                          F
# 7790710              2020-08-12                          F
#
#         paciente_racaCor_valor paciente_endereco_uf  estabelecimento_valor  \
# 40203                    PARDA                   DF                9056963
# 193899                  BRANCA                   DF                  10731
# 324434          SEM INFORMACAO                   DF                  10790
# 420539                  BRANCA                   DF                  10707
# 423941          SEM INFORMACAO                   DF                  10731
# ...                        ...                  ...                    ...
# 7466612                 BRANCA                   DF                  10995
# 7506798                  PARDA                   DF                  10995
# 7610908                 BRANCA                   DF                  10995
# 7710629                 BRANCA                   DF                  11118
# 7790710                 BRANCA                   DF                  11118
#
#                            estabelecimento_razaoSocial  \
# 40203    UNIDADE BASICA DE SAUDE N 01 DE VICENTE PIRES
# 193899            UNIDADE BASICA DE SAUDE N 1 CRUZEIRO
# 324434       UNIDADE BASICA DE SAUDE N 1 SAO SEBASTIAO
# 420539           UNIDADE BASICA DE SAUDE N 1 ASA NORTE
# 423941            UNIDADE BASICA DE SAUDE N 1 CRUZEIRO
# ...                                                ...
# 7466612       UNIDADE BASICA DE SAUDE N 3 DA CEILANDIA
# 7506798       UNIDADE BASICA DE SAUDE N 3 DA CEILANDIA
# 7610908       UNIDADE BASICA DE SAUDE N 3 DA CEILANDIA
# 7710629           UNIDADE BASICA DE SAUDE N 1 DO GUARA
# 7790710           UNIDADE BASICA DE SAUDE N 1 DO GUARA
#
#         estalecimento_noFantasia  ...  estabelecimento_municipio_nome  \
# 40203       UBS 01 VICENTE PIRES  ...                        BRASILIA
# 193899            UBS 1 CRUZEIRO  ...                        BRASILIA
# 324434       UBS 1 SAO SEBASTIAO  ...                        BRASILIA
# 420539           UBS 1 ASA NORTE  ...                        BRASILIA
# 423941            UBS 1 CRUZEIRO  ...                        BRASILIA
# ...                          ...  ...                             ...
# 7466612          UBS 3 CEILANDIA  ...                        BRASILIA
# 7506798          UBS 3 CEILANDIA  ...                        BRASILIA
# 7610908          UBS 3 CEILANDIA  ...                        BRASILIA
# 7710629             UBS 01 GUARA  ...                        BRASILIA
# 7790710             UBS 01 GUARA  ...                        BRASILIA
#
#         estabelecimento_uf vacina_grupoAtendimento_nome vacina_categoria_nome  \
# 40203                   DF                          NaN                   NaN
# 193899                  DF                          NaN                   NaN
# 324434                  DF       Pessoas de 5 a 11 anos                   NaN
# 420539                  DF                          NaN                   NaN
# 423941                  DF                          NaN                   NaN
# ...                    ...                          ...                   ...
# 7466612                 DF                          NaN                   NaN
# 7506798                 DF                          NaN                   NaN
# 7610908                 DF                          NaN                   NaN
# 7710629                 DF                          NaN                   NaN
# 7790710                 DF                          NaN                   NaN
#
#         vacina_lote  vacina_fabricante_nome vacina_dataAplicacao  \
# 40203        GC9016  Pendente Identificação           2022-11-29
# 193899       GC9016  Pendente Identificação           2022-11-23
# 324434       GC9016  Pendente Identificação           2022-11-21
# 420539       GC9016  Pendente Identificação           2022-11-23
# 423941       GC9016  Pendente Identificação           2022-11-23
# ...             ...                     ...                  ...
# 7466612      GC9016  Pendente Identificação           2022-11-25
# 7506798      GC9016  Pendente Identificação           2022-11-29
# 7610908      GC9016  Pendente Identificação           2022-11-29
# 7710629      GC9016  Pendente Identificação           2022-11-25
# 7790710      GC9016  Pendente Identificação           2022-11-25
#
#         vacina_descricao_dose vacina_codigo  vacina_nome
# 40203                 1ª Dose           102          NaN
# 193899                1ª Dose           102          NaN
# 324434                1ª Dose           102          NaN
# 420539                1ª Dose           102          NaN
# 423941                1ª Dose           102          NaN
# ...                       ...           ...          ...
# 7466612               1ª Dose           102          NaN
# 7506798               1ª Dose           102          NaN
# 7610908               1ª Dose           102          NaN
# 7710629               1ª Dose           102          NaN
# 7790710               1ª Dose           102          NaN
#
# [119 rows x 21 columns]

# %% [markdown]
# Busca por ['vacina_codigo'] == 102

# %%
df_vacina_102 = df_estrutra_dados[df_estrutra_dados['vacina_codigo'] == 102]
df_vacina_102['vacina_nome']
# Out:
# 265        COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 506        COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 869        COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 876        COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 1105       COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
#                                  ...
# 7903099    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7903144    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7903153    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7903240    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7903293    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# Name: vacina_nome, Length: 53827, dtype: object

# %%
df_vacina_102['vacina_nome'].unique()
# Out:
# array(['COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS', nan],
#       dtype=object)

# %% [markdown]
# Atualização do nome da Vacina

# %%
indice = df_estrutra_dados.loc[df_vacina_sem_nome.index]
df_estrutra_dados.loc[indice.index, 'vacina_nome'] = 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS'
df_estrutra_dados.loc[indice.index]['vacina_nome']
# Out:
# 40203      COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 193899     COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 324434     COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 420539     COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 423941     COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
#                                  ...
# 7466612    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7506798    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7610908    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7710629    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# 7790710    COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# Name: vacina_nome, Length: 119, dtype: object

# %%
df_vacina_sem_nome = df_estrutra_dados[df_estrutra_dados['vacina_nome'].isnull()]
df_vacina_sem_nome
# Out:
# Empty DataFrame
# Columns: [document_id, paciente_id, paciente_idade, paciente_dataNascimento, paciente_enumSexoBiologico, paciente_racaCor_valor, paciente_endereco_uf, estabelecimento_valor, estabelecimento_razaoSocial, estalecimento_noFantasia, estabelecimento_municipio_codigo, estabelecimento_municipio_nome, estabelecimento_uf, vacina_grupoAtendimento_nome, vacina_categoria_nome, vacina_lote, vacina_fabricante_nome, vacina_dataAplicacao, vacina_descricao_dose, vacina_codigo, vacina_nome]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_estrutra_dados.info()
df_estrutra_dados.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6729203 entries, 0 to 7903354
# Data columns (total 21 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   document_id                       object
#  1   paciente_id                       object
#  2   paciente_idade                    float64
#  3   paciente_dataNascimento           object
#  4   paciente_enumSexoBiologico        category
#  5   paciente_racaCor_valor            object
#  6   paciente_endereco_uf              object
#  7   estabelecimento_valor             int64
#  8   estabelecimento_razaoSocial       object
#  9   estalecimento_noFantasia          object
#  10  estabelecimento_municipio_codigo  int64
#  11  estabelecimento_municipio_nome    object
#  12  estabelecimento_uf                category
#  13  vacina_grupoAtendimento_nome      object
#  14  vacina_categoria_nome             object
#  15  vacina_lote                       object
#  16  vacina_fabricante_nome            object
#  17  vacina_dataAplicacao              object
#  18  vacina_descricao_dose             object
#  19  vacina_codigo                     int64
#  20  vacina_nome                       object
# dtypes: category(2), float64(1), int64(3), object(15)
# memory usage: 1.3+ GB
# document_id                              0
# paciente_id                              0
# paciente_idade                           0
# paciente_dataNascimento                  0
# paciente_enumSexoBiologico               0
# paciente_racaCor_valor                   3
# paciente_endereco_uf                     0
# estabelecimento_valor                    0
# estabelecimento_razaoSocial              0
# estalecimento_noFantasia                 0
# estabelecimento_municipio_codigo         0
# estabelecimento_municipio_nome           0
# estabelecimento_uf                       0
# vacina_grupoAtendimento_nome         43191
# vacina_categoria_nome               330867
# vacina_lote                              0
# vacina_fabricante_nome                   0
# vacina_dataAplicacao                     0
# vacina_descricao_dose                   11
# vacina_codigo                            0
# vacina_nome                              0
# dtype: int64

# %% [markdown]
# ___
